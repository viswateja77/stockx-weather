# %% [markdown]
# <a href="https://colab.research.google.com/github/viswateja77/stockx-weather/blob/main/weather_api_request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary libraries
import requests
import json
import pandas as pd

# %%
url = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=97b5155c1ac049c8b1c210914210207&q=Los Angeles&format=json&date=28-JUNE-2021&enddate=05-JULY-2021&tp=24'
url1 = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=97b5155c1ac049c8b1c210914210207&q=Detroit&format=json&date=28-JUNE-2021&enddate=05-JULY-2021&tp=24'

# %%
x = requests.get(url).text
x1 = requests.get(url1).text

# %%
y = json.loads(x)
y1 = json.loads(x1)
print(y)
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'Los Angeles, United States of America'}], 'weather': [{'date': '2021-06-28', 'astronomy': [{'sunrise': '05:44 AM', 'sunset': '08:08 PM', 'moonrise': '11:45 PM', 'moonset': '09:52 AM', 'moon_phase': 'Waning Gibbous', 'moon_illumination': '68'}], 'maxtempC': '32', 'maxtempF': '89', 'mintempC': '27', 'mintempF': '80', 'avgtempC': '30', 'avgtempF': '86', 'totalSnow_cm': '0.0', 'sunHour': '14.5', 'uvIndex': '7', 'hourly': [{'time': '24', 'tempC': '32', 'tempF': '89', 'windspeedMiles': '6', 'windspeedKmph': '10', 'winddirDegree': '202', 'winddir16Point': 'SSW', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '45', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1002', 'pressureInches': '30', 'cloudcover': '2', 'HeatIndexC': '29', 'HeatIndexF': '85', 'DewPointC': '16', 'DewPointF': '60', 'WindChillC': '29', 'WindChillF': '84', 'WindGustMiles': '7', 'WindGustKmph': '12', 'FeelsLikeC': '29', 'FeelsLikeF': '85', 'uvIndex': '7'}]}, {'date': '2021-06-29', 'astronomy': [{'sunrise': '05:45 AM', 'sunset': '08:08 PM', 'moonrise': 'No moonrise', 'moonset': '10:55 AM', 'moon_phase': 'Waning Gibbous', 'moon_illumination': '60'}], 'maxtempC': '28', 'maxtempF': '83', 'mintempC': '22', 'mintempF': '72', 'avgtempC': '26', 'avgtempF': '79', 'totalSnow_cm': '0.0', 'sunHour': '14.5', 'uvIndex': '7', 'hourly': [{'time': '24', 'tempC': '28', 'tempF': '83', 'windspeedMiles': '7', 'windspeedKmph': '12', 'winddirDegree': '171', 'winddir16Point': 'S', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '59', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1007', 'pressureInches': '30', 'cloudcover': '8', 'HeatIndexC': '26', 'HeatIndexF': '80', 'DewPointC': '16', 'DewPointF': '61', 'WindChillC': '25', 'WindChillF': '77', 'WindGustMiles': '8', 'WindGustKmph': '14', 'FeelsLikeC': '26', 'FeelsLikeF': '80', 'uvIndex': '7'}]}, {'date': '2021-06-30', 'astronomy': [{'sunrise': '05:45 AM', 'sunset': '08:08 PM', 'moonrise': '12:15 AM', 'moonset': '11:56 AM', 'moon_phase': 'Waning Gibbous', 'moon_illumination': '53'}], 'maxtempC': '30', 'maxtempF': '85', 'mintempC': '24', 'mintempF': '75', 'avgtempC': '27', 'avgtempF': '81', 'totalSnow_cm': '0.0', 'sunHour': '14.5', 'uvIndex': '7', 'hourly': [{'time': '24', 'tempC': '30', 'tempF': '85', 'windspeedMiles': '6', 'windspeedKmph': '10', 'winddirDegree': '195', 'winddir16Point': 'SSW', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}], 'weatherDesc': [{'value': 'Sunny'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '58', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1010', 'pressureInches': '30', 'cloudcover': '0', 'HeatIndexC': '27', 'HeatIndexF': '81', 'DewPointC': '17', 'DewPointF': '63', 'WindChillC': '26', 'WindChillF': '79', 'WindGustMiles': '7', 'WindGustKmph': '11', 'FeelsLikeC': '27', 'FeelsLikeF': '81', 'uvIndex': '7'}]}, {'date': '2021-07-01', 'astronomy': [{'sunrise': '05:46 AM', 'sunset': '08:08 PM', 'moonrise': '12:43 AM', 'moonset': '12:53 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '51'}], 'maxtempC': '30', 'maxtempF': '85', 'mintempC': '24', 'mintempF': '74', 'avgtempC': '27', 'avgtempF': '81', 'totalSnow_cm': '0.0', 'sunHour': '14.5', 'uvIndex': '7', 'hourly': [{'time': '24', 'tempC': '30', 'tempF': '85', 'windspeedMiles': '6', 'windspeedKmph': '9', 'winddirDegree': '216', 'winddir16Point': 'SW', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png ...

# %%
df = pd.json_normalize(y['data'],record_path=(['weather']))
df0= pd.json_normalize(y['data'],record_path=(['weather']))

# %%
df['city'] = 'Los Angeles, United States of America'
df0['city'] = 'Detroit, United States of America'
df1 = pd.concat([df,df0])
df1
# Out:
#          date  ...                                   city
# 0  2021-06-28  ...  Los Angeles, United States of America
# 1  2021-06-29  ...  Los Angeles, United States of America
# 2  2021-06-30  ...  Los Angeles, United States of America
# 3  2021-07-01  ...  Los Angeles, United States of America
# 4  2021-07-02  ...  Los Angeles, United States of America
# 5  2021-07-03  ...  Los Angeles, United States of America
# 6  2021-07-04  ...  Los Angeles, United States of America
# 7  2021-07-05  ...  Los Angeles, United States of America
# 0  2021-06-28  ...      Detroit, United States of America
# 1  2021-06-29  ...      Detroit, United States of America
# 2  2021-06-30  ...      Detroit, United States of America
# 3  2021-07-01  ...      Detroit, United States of America
# 4  2021-07-02  ...      Detroit, United States of America
# 5  2021-07-03  ...      Detroit, United States of America
# 6  2021-07-04  ...      Detroit, United States of America
# 7  2021-07-05  ...      Detroit, United States of America
#
# [16 rows x 13 columns]

# %%
df2 = df1.drop(['astronomy','hourly'],axis = 1)
df2
# Out:
#          date maxtempC  ... uvIndex                                   city
# 0  2021-06-28       32  ...       7  Los Angeles, United States of America
# 1  2021-06-29       28  ...       7  Los Angeles, United States of America
# 2  2021-06-30       30  ...       7  Los Angeles, United States of America
# 3  2021-07-01       30  ...       7  Los Angeles, United States of America
# 4  2021-07-02       30  ...       7  Los Angeles, United States of America
# 5  2021-07-03       30  ...       7  Los Angeles, United States of America
# 6  2021-07-04       29  ...       7  Los Angeles, United States of America
# 7  2021-07-05       30  ...       7  Los Angeles, United States of America
# 0  2021-06-28       32  ...       7      Detroit, United States of America
# 1  2021-06-29       28  ...       7      Detroit, United States of America
# 2  2021-06-30       30  ...       7      Detroit, United States of America
# 3  2021-07-01       30  ...       7      Detroit, United States of America
# 4  2021-07-02       30  ...       7      Detroit, United States of America
# 5  2021-07-03       30  ...       7      Detroit, United States of America
# 6  2021-07-04       29  ...       7      Detroit, United States of America
# 7  2021-07-05       30  ...       7      Detroit, United States of America
#
# [16 rows x 11 columns]

# %%
df2.to_csv('weather.csv',index = False)

# %%
import os
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/drive/My Drive/Colab Notebooks/service-account-file.json"
# Out:
#  service-account-file.json   Untitled  'weather api request.ipynb'

# %%
from google.cloud import storage


def upload_blob(bucket_name, source_file_name, destination_blob_name):
  """Uploads a file to the bucket."""
  storage_client = storage.Client()
  bucket = storage_client.get_bucket(bucket_name)
  blob = bucket.blob(destination_blob_name)

  blob.upload_from_filename(source_file_name)

  print('File {} uploaded to {}.'.format(
      source_file_name,
      destination_blob_name))
upload_blob('stockx_weather_bucket','weather.csv','weather')
# Out:
# File weather.csv uploaded to weather.
